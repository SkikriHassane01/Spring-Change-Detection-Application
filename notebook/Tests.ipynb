# %% [markdown]
# # File Uploaded Handler

# %%
import sys
from pathlib import Path
import os

# %%
root_path = Path(os.getcwd()).resolve().parent
sys.path.append(str(root_path))

# %%
from src.file_handler import FileHandler


old_path = r"D:\03. Projects\Spring-Change-Detection-Application\data\VP\old_1.xls"

new_path = r"D:\03. Projects\Spring-Change-Detection-Application\data\VP\new_1.xls"

# %%
#  validate the new excel file
is_valid, msg ,df = FileHandler.validate_excel_file(new_path, "new")
print(is_valid)
print(msg)
# Out:
# True
# File uploaded successfully.

# %%
df.head()
# Out:
#           Silhouette Hybridation  Moteur Boite       Niveau Charge utile  \
# 0  L1 bas Europe 5pl         STT  DV5RCf   MB6  VP2_PCD_FCA           TT
# 1  L1 bas Europe 5pl         STT  DV5RCf   MB6  VP2_PCD_FCA           TT
# 2  L1 bas Europe 5pl         STT  DV5RCf   MB6  VP2_PCD_FCA           TT
# 3  L1 bas Europe 5pl         STT  DV5RCf   MB6  VP2_PCD_FCA           TT
# 4  L1 bas Europe 5pl         STT  DV5RCf   MB6  VP3_PCD_FCA           TT
#
#   Dépollution Plaque de protection tôle sous GMP Pavillon multifonction  \
# 0         E64                                  X                    NaN
# 1         E64                                NaN                    NaN
# 2         E64                                  X                    NaN
# 3         E64                                NaN                    NaN
# 4         E64                                  X                    NaN
#
#   2e PLC Gauche Chauffage additionnel type WEBASTO  Flex   Pn   Référence  \
# 0             X                                NaN    55  438  9821112880
# 1             X                                NaN    55  438  9821112880
# 2           NaN                                NaN    55  438  9821112880
# 3           NaN                                NaN    55  438  9821112880
# 4             X                                  X    55  457  9821112980
#
#    Ecart\nd'assiette  Masse d'option\nprise en compte  Masse totale\nd'option  \
# 0          -0.231695                           16.117                  25.317
# 1          -2.241901                            7.352                  25.317
# 2          -1.917837                            8.765                  25.317
# 3          -3.928042                            0.000                  25.317
# 4          -3.888774                           20.461                  31.433
#
#    Masse suspendue en charge de référence  Assiette mini  Assiette MAXI
# 0                                896.3406       2.632835      -3.096225
# 1                                887.5756       0.622630      -5.106431
# 2                                888.9886       0.946694      -4.782367
# 3                                880.2236      -1.063512      -6.792573
# 4                                917.6866      -1.024244      -6.753304
